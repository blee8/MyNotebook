# %% [markdown]
# ## Lego Model
# - [출처](https://tykimos.github.io/2017/01/27/MLP_Layer_Talk/)
# - [출처1](http://cs231n.github.io/neural-networks-1/)

# %% [markdown]
# ## 다중퍼셉트론 레이어
# * 케라스의 layer
# * 데이터 구조는 모델, 모델을 구성하는 것이 레이어
# * Dense Layer (전결합층)
# ---

# %% [markdown]
# * axon (축삭돌기) : 팔처럼 몸체에서 뻗어나와 다른 뉴런의 수상돌기와 연결됩니다.
# * dendrite (수상돌기) : 다른 뉴런의 축삭 돌기와 연결되며, 몸체에 나뭇가지 형태로 붙어 있습니다.
# * synapse (시냅스) : 축사돌기와 수상돌기가 연결된 지점입니다. 여기서 한 뉴런이 다른 뉴런으로 신호가 전달됩니다.

# %%
from IPython.display import Image
# %matplotlib inline
Image(filename='../img/neuron.png', width=300)

# %% [markdown]
# ### 세개의 신호, 하나의 neuron
# ![하나의 신호](https://github.com/blee8/MyNotebook/blob/master/img/MLP_lego_1.png?raw=1)
#
# Image(filename='../img/MLP_lego_1.png', width=300)

# %% [markdown]
# ### 세개의 신호. 2개의 뉴런
# ![하나의 신호](https://github.com/blee8/MyNotebook/blob/master/img/MLP_lego_2.png?raw=1)
#
# ![하나의 신호](https://github.com/blee8/MyNotebook/blob/master/img/MLP__lego_3.png?raw=1)
# Image(filename='../img/MLP__lego_1.png', width=300)

# %% [markdown]
# ## 입출력을 연결하는 Dense layer
# ###
# ![신호](https://github.com/blee8/MyNotebook/blob/master/img/MLP__lego_3.png?raw=1)
#
#
#
#
# # 이진분류  sigmoid
# Image(filename='../img/MLP__lego_4.png', width=300)

# %%
# 다중클래스 분류  softmax
Image(filename='../img/MLP__lego_5.png', width=300)
