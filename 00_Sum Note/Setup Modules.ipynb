# %% [markdown]
# # Setup Modules
#
# ### <font color='blue'>Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow</font>
# ##### by Aurélien Géron (2019)
# * import a few common modules,
# * ensure MatplotLib plots figures inline and
# * prepare a function to save the figures
# * check that Python 3.5 or later is installed
# * Scikit-Learn ≥0.20

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# %%
# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

"""
# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "training_linear_models"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")
"""
# Out:
# '\n# Where to save the figures\nPROJECT_ROOT_DIR = "."\nCHAPTER_ID = "training_linear_models"\nIMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)\nos.makedirs(IMAGES_PATH, exist_ok=True)\n\ndef save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):\n    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)\n    print("Saving figure", fig_id)\n    if tight_layout:\n        plt.tight_layout()\n    plt.savefig(path, format=fig_extension, dpi=resolution)\n\n# Ignore useless warnings (see SciPy issue #5998)\nimport warnings\nwarnings.filterwarnings(action="ignore", message="^internal gelsd")\n'

# %%
"""
# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"
print('sklearn Version', sklearn.__version__)

from IPython.display import Image
#%matplotlib inline
#Image(filename='../img/neuron.png', width=300)
"""
# Out:
# '\n# Scikit-Learn ≥0.20 is required\nimport sklearn \nassert sklearn.__version__ >= "0.20" \nprint(\'sklearn Version\', sklearn.__version__) \n\nfrom IPython.display import Image \n#%matplotlib inline\n#Image(filename=\'../img/neuron.png\', width=300)\n'

# %% [markdown]
# ***
# ### <font color='blue'>Python-machine-learning</font>(3rd edition)
# ##### by Sebastian Raschka   [[Web]](sebastianraschka.com)  [[git]](https://github.com/rasbt/python-machine-learning-book-3rd-edition)

# %% [markdown]
# * ###### magic command [[magic command]](https://sosomemo.tistory.com/60)
# * ###### water mark
# * ###### font <font color='magenta'> color </font>
# This is *italic*.
# This is <span style="color: red">written in red</span>.
# <font color='green'>test blue color font</font>
#
# ###### STAT 453: Deep Learning (Spring 2020)
# ###### Instructor: Sebastian Raschka (sraschka@wisc.edu)
# ###### Course website: http://pages.stat.wisc.edu/~sraschka/teaching/stat453-ss2020/
# ###### GitHub repository: https://github.com/rasbt/stat453-deep-learning-ss20

# %%
# %lsmagic

# %%
# !pip install watermark
# Out:
# ...
#   Using cached watermark-2.0.2-py2.py3-none-any.whl (5.3 kB)
# ...

# %%
# jupyter notebook magic commend %
# %load_ext watermark

# %%
# %watermark
# Out:
# 2020-09-20T12:55:42+09:00
#
# CPython 3.8.5
# IPython 7.18.1
#
# compiler   : MSC v.1916 64 bit (AMD64)
# system     : Windows
# release    : 10
# machine    : AMD64
# processor  : Intel64 Family 6 Model 158 Stepping 10, GenuineIntel
# CPU cores  : 12
# interpreter: 64bit

# %%
# %watermark -a "blee" -u -d -p numpy,pandas,matplotlib
#%watermark -a 'Sebastian Raschka' -v -p torch,pandas,matplotlib
# Out:
# blee
# last updated: 2020-09-20
#
# numpy 1.16.6
# pandas not installed
# matplotlib 3.3.2

# %%
from IPython.display import Image
# %matplotlib inline
Image(filename='../img/neuron.png', width=300)

# %% [markdown]
# ***
# ### <font color='blue'>Introduction to Machine Learning with Python</font>
# ##### by Andreas C. Müller, Sarah Guido
# * ###### machine-learning application with Python and *the scikit-learn library*
# * ###### 그래프와 데이터셋을 위한 mglearn 라이브러리
# * ###### preamble.py

# %%
# preamble.py

from IPython.display import set_matplotlib_formats, display
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from cycler import cycler
import mglearn

# 맷플롯립 한글 폰트 지정
import matplotlib
matplotlib.rc('font', family='NanumBarunGothic')
matplotlib.rcParams['axes.unicode_minus'] = False

set_matplotlib_formats('pdf', 'png')
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
plt.rcParams['image.cmap'] = "viridis"
plt.rcParams['image.interpolation'] = "none"
plt.rcParams['savefig.bbox'] = "tight"
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['legend.numpoints'] = 1
plt.rc('axes', prop_cycle=(
        cycler('color', mglearn.plot_helpers.cm_cycle.colors) +
        cycler('linestyle', ['-', '-', "--", (0, (3, 3)), (0, (1.5, 1.5))])))


np.set_printoptions(precision=3, suppress=True)

pd.set_option("display.max_columns", 8)
pd.set_option('precision', 2)

__all__ = ['np', 'mglearn', 'display', 'plt', 'pd']

# %% [markdown]
# ***
# ### <font color='blue'>Dive into Deep Learning</font>
# ##### by Aston Zhang and Zachary C. Lipton and Mu Li and Alexander J. Smola
#  @book{zhang2020dive,
#     title={Dive into Deep Learning},
#     author={Aston Zhang and Zachary C. Lipton and Mu Li and Alexander J. Smola},
#     note={\url{https://d2l.ai}},
#     year={2020}
# }
#
# * ###### Provides NumPy/MXNet, PyTorch, and TensorFlow implementations
# * ###### timer
#
# ```
# !pip install d2l==0.13.2 -f https://d2l.ai/whl.html # installing d2l
# !pip install -U mxnet-cu101mkl==1.6.0  # updating mxnet to at least v1.6
#
# from d2l import mxnet as d2l
# from mxnet import autograd, gluon, np, npx
# npx.set_np()
# ```
# ```
# #----------berkeley-stat157-------------------------------------
# import mxnet as mx
# from mxnet import nd
# %matplotlib inline
# from matplotlib import pyplot as plt
# from IPython import display
# display.set_matplotlib_formats('svg')
# #-----------------------------------------------------------
# import d2l
# from mxnet import autograd, gluon, init, nd
# from mxnet.gluon import data as gdata, nn
# from mxnet.gluon import loss as gloss
# import os
# import sys
# import time
# #-----------------------------
# import sys
# sys.path.insert(0, '..')
#
# import d2l
# from mxnet import gluon, init, nd
# from mxnet.gluon import data as gdata, loss as gloss, nn, rnn, utils as gutils
# from mxnet.contrib import text
# import os
# import tarfile
#
# ```

# %%
# setup.py
from setuptools import setup, find_packages
import re
import os

requirements = [
    'jupyter',
    'numpy',
    'matplotlib',
    'pandas'
]

# don't import d2l to get __version__ since it has deps
ver_re = re.compile("__version__ = \"([\.\d]+).*")
with open(os.path.join('d2l','__init__.py')) as f:
    lines = f.readlines()
for l in lines:
    m = ver_re.match(l)
    if m:
        version = m.group(1)
        break
setup(
    name='d2l',
    version=version,
    python_requires='>=3.5',
    author='D2L Developers',
    author_email='d2l.devs@gmail.com',
    url='https://d2l.ai',
    description='Dive into Deep Learning',
    license='MIT-0',
    packages=find_packages(),
    zip_safe=True,
    install_requires=requirements,
)

# %% [markdown]
# * ##### timer

# %%
class Timer:  #@save
    """Record multiple running times."""
    def __init__(self):
        self.times = []
        self.start()

    def start(self):
        """Start the timer."""
        self.tik = time.time()

    def stop(self):
        """Stop the timer and record the time in a list."""
        self.times.append(time.time() - self.tik)
        return self.times[-1]

    def avg(self):
        """Return the average time."""
        return sum(self.times) / len(self.times)

    def sum(self):
        """Return the sum of time."""
        return sum(self.times)

    def cumsum(self):
        """Return the accumulated times."""
        return np.array(self.times).cumsum().tolist()

# %% [markdown]
# ***
# ### <font color='blue'> Deep Learning with Python</font>
# ##### by François Chollet
#
# * ###### **Keras** creator and Google AI researcher
#
#
# ```
# import keras
# keras.__version__
#
# from keras.datasets import mnist
# (train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# ```
# ```
# #----------------------------------
# import matplotlib.pyplot as plt
#
# # b+ is for "blue cross"
# plt.plot(epochs, original_val_loss, 'b+', label='Original model')
# # "bo" is for "blue dot"
# plt.plot(epochs, smaller_model_val_loss, 'bo', label='Smaller model')
# plt.xlabel('Epochs')
# plt.ylabel('Validation loss')
# plt.legend()
#
# plt.show()
# #----------------------------------
#
# ```
